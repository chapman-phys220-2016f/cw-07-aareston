# %% [markdown]
# # Classwork 7
# ## Aaron Grisez and Preston Kamada

# %%
import nonhomogenous_linear_ODE
import nonlinear_ODE as nl
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem 1

# %%
nonhomogenous_linear_ODE.solve()
# Out:
# nonhomogenous_linear_ODE.py:17: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   u = np.zeros(num_points)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-38e0eeeaa9c1> in <module>()
# ----> 1 nonhomogenous_linear_ODE.solve()
#
# /projects/492d2afd-3c56-4b42-a7e2-9d093615ed49/cw-07-aareston/nonhomogenous_linear_ODE.py in solve()
#      30     delta_t = .25
#      31
# ---> 32     print euler(uo, to, tf, delta_t)
#
# /projects/492d2afd-3c56-4b42-a7e2-9d093615ed49/cw-07-aareston/nonhomogenous_linear_ODE.py in euler(uo, to, tf, delta_t)
#      20     for h in range(0, int(num_points), 1):
#      21
# ---> 22         u[h+1] = u[h] + ((2 * u[h] - 1) * t_array) * delta_t
#      23
#      24     return u
#
# ValueError: setting an array element with a sequence.

# %% [markdown]
# ### Problem 2
# Solve the nonlinear ODE $u' = u^q$ using Euler's Forward Method.

# %%
xvals = np.arange(0,6,0.01)
approx = nl.euler(lambda t, x: x, 1.0, 0.0, 6.0, 0.01)
exact = np.exp(xvals)
plt.plot(xvals, approx, 'r')
plt.plot(xvals, exact, 'b')

# %%
xvals = np.arange(0,6,0.1)
approx = nl.euler(lambda t, x: x, 1.0, 0.0, 6.0, 0.1)
exact = np.exp(xvals)
plt.plot(xvals, approx, 'r')
plt.plot(xvals, exact, 'b')

# %%
xvals = np.arange(0,.9,0.1)
approx = nl.euler(lambda t, x: x ** 2, 1.0, 0.0, 0.9, 0.1)
exact = np.exp(xvals)
plt.plot(xvals, approx, 'r')
plt.plot(xvals, exact, 'b')

# %%
xvals = np.arange(0,.9,0.01)
approx = nl.euler(lambda t, x: x ** 2, 1.0, 0.0, 0.9, 0.01)
exact = np.exp(xvals)
plt.plot(xvals, approx, 'r')
plt.plot(xvals, exact, 'b')

# %%
xvals = np.arange(0,.4,0.01)
approx = nl.euler(lambda t, x: x ** 3, 1.0, 0.0, 0.4, 0.01)
exact = np.exp(xvals)
plt.plot(xvals, approx, 'r')
plt.plot(xvals, exact, 'b')
